# %% [markdown]
# # Project 1 Data Analytics Boot Camp
#
# * Explore the data for the DC_Properties.csv dataset.
# * Begin to prepare the data (clean, manipulate, transform, etc.) for future analysis.
# * What interesting things can you conclude about the data?

# %%
#import libraries
import pandas as pd
import numpy as np

# %%
#load csv file data with headers

location = "datasets/DC_Properties.csv"
df = pd.read_csv(location)
# Out:
# /Users/sjbostian/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# See what the data looks like
df.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL  ...  LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0  ... -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0  ... -77.040764       Old City 2   040 D Old City 2
# 2  1910.0   2009.0  ... -77.040678       Old City 2   040 D Old City 2
# 3  1900.0   2003.0  ... -77.040629       Old City 2   040 D Old City 2
# 4  1913.0   2012.0  ... -77.039361       Old City 2   040 D Old City 2
#
#    CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE          X          Y QUADRANT
# ...

# %%
# Statistical description of the data  
df.describe()
# Out:
#           Unnamed: 0         BATHRM      HF_BATHRM      NUM_UNITS  \
# count  158957.000000  158957.000000  158957.000000  106696.000000
# mean    79478.000000       1.810678       0.458237       1.198039
# std     45887.077707       0.976396       0.587571       0.596924
# min         0.000000       0.000000       0.000000       0.000000
# 25%     39739.000000       1.000000       0.000000       1.000000
# 50%     79478.000000       2.000000       0.000000       1.000000
# 75%    119217.000000       2.000000       1.000000       1.000000
# max    158956.000000      14.000000      11.000000       6.000000
#
#                ROOMS          BEDRM            AYB       YR_RMDL  \
# count  158957.000000  158957.000000  158686.000000  80928.000000
# mean        6.187736       2.732506    1941.987579   1998.243537
# std         2.618165       1.358864      33.640234     16.575786
# min         0.000000       0.000000    1754.000000     20.000000
# ...

# %%
# How many rows and columns?
df.shape
# Out:
# (158957, 49)

# %%
# How many nulls are in each variable?
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# BATHRM                     0
# HF_BATHRM                  0
# HEAT                       0
# AC                         0
# NUM_UNITS              52261
# ROOMS                      0
# BEDRM                      0
# AYB                      271
# YR_RMDL                78029
# EYB                        0
# STORIES                52305
# SALEDATE               26770
# PRICE                  60741
# QUALIFIED                  0
# SALE_NUM                   0
# GBA                    52261
# BLDG_NUM                   0
# STYLE                  52261
# STRUCT                 52261
# GRADE                  52261
# CNDTN                  52261
# EXTWALL                52261
# ROOF                   52261
# INTWALL                52261
# KITCHENS               52262
# FIREPLACES                 0
# USECODE                    0
# LANDAREA                   0
# GIS_LAST_MOD_DTTM          0
# SOURCE                     0
# CMPLX_NUM             106696
# ...

# %%
# Are there duplicates in the addresses?
df.duplicated(['FULLADDRESS'])
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 158927     True
# 158928     True
# 158929     True
# 158930     True
# 158931     True
# 158932     True
# 158933     True
# 158934     True
# 158935     True
# 158936     True
# 158937     True
# 158938     True
# 158939     True
# 158940     True
# 158941     True
# 158942     True
# 158943     True
# 158944     True
# 158945     True
# 158946     True
# 158947     True
# 158948     True
# 158949     True
# 158950     True
# ...

# %%
# Info on the duplicate addresses
dup_addy = df.duplicated(['FULLADDRESS'])
df.loc[dup_addy]
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 1426          1426       2          1     Forced Air  Y        1.0      6
# 1449          1449       4          2     Forced Air  Y        2.0     10
# 1492          1492       2          1     Forced Air  Y        1.0      4
# 1807          1807       1          0     Forced Air  Y        1.0      3
# 2041          2041       1          0  Hot Water Rad  N        1.0      5
# 2108          2108       3          0      Warm Cool  Y        2.0      6
# 2109          2109       3          1      Warm Cool  Y        2.0      8
# 2728          2728       2          0  Hot Water Rad  N        1.0      6
# 2758          2758       2          1  Hot Water Rad  N        2.0      8
# 2961          2961       2          1     Forced Air  Y        1.0      9
# 3560          3560       1          0  Hot Water Rad  N        1.0      3
# 3727          3727       4          0  Hot Water Rad  N        4.0     16
# ...

# %%
# What are the actual addresses of the duplicates?
df[dup_addy]['FULLADDRESS']
# Out:
# 1426                             NaN
# 1449                             NaN
# 1492                             NaN
# 1807             1800 11TH STREET NW
# 2041                1301 S STREET NW
# 2108                             NaN
# 2109                             NaN
# 2728         1914 1/2 13TH STREET NW
# 2758                             NaN
# 2961                             NaN
# 3560                 945 O STREET NW
# 3727                             NaN
# 3816                             NaN
# 3817                             NaN
# 3862                             NaN
# 4034                             NaN
# 4368                             NaN
# 4798                             NaN
# 4992               435 1ST STREET SE
# 5341                             NaN
# 5802                             NaN
# 6980                             NaN
# 7761                             NaN
# 9049            312 MILLERS COURT NE
# 9050            312 MILLERS COURT NE
# ...

# %%
# What properties are less than $50,000?
df[df["PRICE"] < 50000]
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 20              20       3          1  Hot Water Rad  Y        1.0     14
# 25              25       1          0  Hot Water Rad  N        1.0      8
# 433            433       3          0  Hot Water Rad  N        3.0     11
# 638            638       2          0      Warm Cool  Y        1.0      9
# 1186          1186       2          0     Forced Air  Y        2.0      6
# 1567          1567       3          0  Hot Water Rad  N        2.0     11
# 1593          1593       1          0  Hot Water Rad  N        1.0      5
# 1916          1916       4          0  Hot Water Rad  N        2.0     12
# 2446          2446       2          0  Hot Water Rad  N        1.0     10
# 2681          2681       3          0  Hot Water Rad  N        2.0     12
# 3293          3293       2          0     Forced Air  N        2.0      7
# 3330          3330       2          1  Hot Water Rad  N        1.0      9
# ...

# %%
# What properties have more than 10 bathrooms and more than 10 rooms?
df[(df["BATHRM"] > 10) & (df["ROOMS"] > 10)]
# Out:
#        Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 683           683      11          2  Hot Water Rad  Y        2.0     19
# 3329         3329      11          1     Forced Air  Y        4.0     23
# 34320       34320      12          3     Forced Air  Y        1.0     48
# 36673       36673      11          1      Warm Cool  Y        1.0     25
# 36674       36674      12          3      Warm Cool  Y        1.0     19
# 37118       37118      11          1      Warm Cool  Y        1.0     26
# 37579       37579      11          0      Warm Cool  Y        1.0     16
# 40031       40031      14          6      Warm Cool  Y        1.0     39
# 40431       40431      11          2      Warm Cool  Y        1.0     23
# 54330       54330      11          0        Ht Pump  Y        4.0     14
#
#        BEDRM     AYB  YR_RMDL  ...  LONGITUDE               ASSESSMENT_NBHD  \
# 683       10  1906.0   2000.0  ... -77.046856                    Old City 2
# ...

# %%
# What is the address of the properties with more than 10 bathrooms and more than 10 rooms?
df[(df["BATHRM"] > 10) & (df["ROOMS"] > 10)]["FULLADDRESS"]
# Out:
# 683          1630 21ST STREET NW
# 3329             605 P STREET NW
# 34320                        NaN
# 36673        2211 30TH STREET NW
# 36674        2221 30TH STREET NW
# 37118        2501 30TH STREET NW
# 37579     2838 MCGILL TERRACE NW
# 40031    1940 SHEPHERD STREET NW
# 40431      2221 KALORAMA ROAD NW
# 54330            511 U STREET NW
# Name: FULLADDRESS, dtype: object

# %%
# In what quadrant of the city are the properties with more than 10 bathrooms and more than 10 rooms?
df[(df["BATHRM"] > 10) & (df["ROOMS"] > 10)]["QUADRANT"]
# Out:
# 683      NW
# 3329     NW
# 34320    NW
# 36673    NW
# 36674    NW
# 37118    NW
# 37579    NW
# 40031    NW
# 40431    NW
# 54330    NW
# Name: QUADRANT, dtype: object

# %%
# What is the average number of bathrooms in each quadrant of the city?
df.groupby('QUADRANT')['BATHRM'].mean()
# Out:
# QUADRANT
# NE    1.701898
# NW    1.910749
# SE    1.674478
# SW    1.501591
# Name: BATHRM, dtype: float64

# %%
# What is the average number of bathrooms in houses in each year houses were built?
print(df.groupby('EYB')['BATHRM'].mean())
# Out:
# EYB
# 1800    1.000000
# 1820    1.666667
# 1865    1.000000
# 1870    1.600000
# 1875    1.660000
# 1876    1.166667
# 1880    1.145455
# 1885    1.117647
# 1886    2.250000
# 1887    1.608696
# 1890    1.153465
# 1891    1.121569
# 1893    1.176471
# 1895    1.033019
# 1898    1.000000
# 1899    1.250000
# 1900    1.405604
# 1901    1.268657
# 1902    1.000000
# 1903    1.111111
# 1904    1.142857
# 1905    1.282609
# 1906    1.471698
# 1907    1.369565
# 1908    1.224543
# 1909    1.252809
# 1910    1.326599
# 1911    1.317391
# 1912    1.419355
# 1913    1.105263
#           ...
# 1989    1.554140
# 1990    2.024242
# 1991    2.303324
# 1992    3.009375
# 1993    2.717514
# 1994    2.335312
# 1995    2.851541
# 1996    3.213793
# 1997    2.939024
# 1998    2.997849
# 1999    2.729358
# 2000    3.369021
# 2001    2.946237
# 2002    1.775049
# 2003    1.852484
# 2004    1.557460
# 2005    1.531484
# 2006    1.673614
# 2007    1.738919
# 2008    1.766762
# 2009    1.970297
# ...

# %%
#boolean values for if there's another row with the exact values in each column
dupe = df.duplicated()

# %%
# Are there any exact duplicate rows in the dataset?
df.loc[dupe]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]
